# %% [markdown]
# # Imports

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import os
import optuna

# %% [markdown]
# # Loading the data

# %%
folder = "/kaggle/input/ftml-dataset/data/classification"
X_test = np.load(os.path.join(folder, "X_test.npy"))
y_test = np.load(os.path.join(folder, "y_test.npy"))
X_train = np.load(os.path.join(folder, "X_train.npy"))
y_train = np.load(os.path.join(folder, "y_train.npy"))

print("size of the dataset:", len(y_train))
print("number of features:", len(X_train[0]))
# Out:
# size of the dataset: 500
# number of features: 30

# %%
plt.subplot(1,2,1)
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='viridis', edgecolor='k', s=50)
plt.title('First two features of the dataset')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

plt.show()

# %%
plt.subplot(1,2,1)
plt.scatter(X_train[:,2], X_train[:,3], c=y_train, cmap='viridis', edgecolor='k', s=50)
plt.title('Two other features of the dataset')
plt.xlabel('Feature 3')
plt.ylabel('Feature 4')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # First method

# %% [markdown]
# We need to classify labeled and numerical data, with a have a moderate-sized dataset (500 data). A KNeighbors classifier can be a good start for the classification.

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.84      0.77       201
#            1       0.88      0.78      0.82       299
#
#     accuracy                           0.80       500
#    macro avg       0.80      0.81      0.80       500
# weighted avg       0.81      0.80      0.80       500

# %% [markdown]
# # Second method

# %% [markdown]
# This dataset have a lot of features (30). This can be a issue with the majority of the classification models. However, SVC is effective in high dimensional spaces.
#
# Let's try the svc by default and see the performances:

# %%
svc_rbf = SVC()
svc_rbf.fit(X_train, y_train)

y_pred = svc_rbf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.86      0.78       201
#            1       0.89      0.77      0.82       299
#
#     accuracy                           0.80       500
#    macro avg       0.80      0.81      0.80       500
# weighted avg       0.82      0.80      0.81       500

# %% [markdown]
# It's good but we can do better.
#
# SVC can use various kernel functions (polynomial, RBF, sigmoid) to handle non-linear relationships or linear (linear) relationships. We just need to find the kernel function that works best for our dataset. For that we can use optuna to search for the best hyperparameters.
#
# We want to maximize the accuracy.
#
# Concerning the hyper parameters choices for optuna:
# - we remove rbf because we want to see if we can obtain better results without it
# - we remove linear because the data are cleary not linear (see the graph)
# - we remove scale for gamma because we have a large number of features and auto is more useful in this situation
#
# The limits for C and degree are the results of a lot of tests. Limits that are superior produced inferior results.

# %%
#We want a validation dataset to see the performances.
X_train2, X_val, y_train2, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

def objective(trial):
    params = {
        'kernel': trial.suggest_categorical('kernel', ['poly', 'sigmoid']),
        'C': trial.suggest_int('C', 1, 5),
        'degree': trial.suggest_int('degree', 2, 5)
    }
    
    clf = SVC(**params)
    
    clf.fit(X_train2, y_train2)
    accuracy = clf.score(X_val, y_val)
    
    return accuracy

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, n_jobs=-1)

best_params = study.best_params

print("Best parameters found by Optuna:")
print(best_params)
print("Best cross-validation accuracy on the validation set:")
print(study.best_value)

svc_best = SVC(kernel=best_params['kernel'], C=best_params['C'], gamma='auto', degree=best_params.get('degree', 3))
svc_best.fit(X_train, y_train)
# Out:
# [I 2024-06-19 17:43:01,275] A new study created in memory with name: no-name-89d5d070-1786-4473-bd38-61fdc6f3f636
# [I 2024-06-19 17:43:01,300] Trial 1 finished with value: 0.76 and parameters: {'kernel': 'poly', 'C': 2, 'degree': 3}. Best is trial 1 with value: 0.76.
# [I 2024-06-19 17:43:01
and parameters: {'kernel': 'poly', 'C': 2, 'degree': 2}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,243] Trial 50 finished with value: 0.66 and parameters: {'kernel': 'poly', 'C': 2, 'degree': 2}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,322] Trial 53 finished with value: 0.7 and parameters: {'kernel': 'poly', 'C': 3, 'degree': 4}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,328] Trial 52 finished with value: 0.7 and parameters: {'kernel': 'poly', 'C': 3, 'degree': 4}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,338] Trial 54 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,345] Trial 51 finished with value: 0.67 and parameters: {'kernel': 'poly', 'C': 2, 'degree': 4}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,418] Trial 55 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,420] Trial 57 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,430] Trial 56 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,443] Trial 58 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,518] Trial 60 finished with value: 0.64 and parameters: {'kernel': 'sigmoid', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,520] Trial 59 finished with value: 0.64 and parameters: {'kernel': 'sigmoid', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,530] Trial 62 finished with value: 0.64 and parameters: {'kernel': 'sigmoid', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,533] Trial 61 finished with value: 0.64 and parameters: {'kernel': 'sigmoid', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,627] Trial 64 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,636] Trial 63 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,641] Trial 65 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,653] Trial 66 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,744] Trial 67 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,760] Trial 69 finished with value: 0.76 and parameters: {'kernel': 'poly', 'C': 2, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,763] Trial 70 finished with value: 0.76 and parameters: {'kernel': 'poly', 'C': 2, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,764] Trial 68 finished with value: 0.76 and parameters: {'kernel': 'poly', 'C': 2, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,861] Trial 71 finished with value: 0.76 and parameters: {'kernel': 'poly', 'C': 2, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,869] Trial 73 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,874] Trial 72 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,879] Trial 74 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,983] Trial 77 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,992] Trial 75 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:02,996] Trial 76 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,005] Trial 78 finished with value: 0.74 and parameters: {'kernel': 'poly', 'C': 4, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,104] Trial 80 finished with value: 0.66 and parameters: {'kernel': 'poly', 'C': 4, 'degree': 2}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,112] Trial 79 finished with value: 0.74 and parameters: {'kernel': 'poly', 'C': 4, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,113] Trial 82 finished with value: 0.64 and parameters: {'kernel': 'poly', 'C': 5, 'degree': 2}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,114] Trial 81 finished with value: 0.64 and parameters: {'kernel': 'poly', 'C': 5, 'degree': 2}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,217] Trial 83 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,224] Trial 84 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,230] Trial 86 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,242] Trial 85 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,334] Trial 87 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,348] Trial 88 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,349] Trial 89 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,353] Trial 90 finished with value: 0.63 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 4}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,450] Trial 91 finished with value: 0.63 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 4}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,458] Trial 94 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,466] Trial 92 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,467] Trial 93 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,570] Trial 96 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,572] Trial 95 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,574] Trial 97 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,576] Trial 98 finished with value: 0.77 and parameters: {'kernel': 'poly', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# [I 2024-06-19 17:43:03,610] Trial 99 finished with value: 0.64 and parameters: {'kernel': 'sigmoid', 'C': 1, 'degree': 3}. Best is trial 20 with value: 0.77.
# Best parameters found by Optuna:
# {'kernel': 'poly', 'C': 1, 'degree': 3}
# Best cross-validation accuracy on the validation set:
# 0.77
# SVC(C=1, gamma='auto', kernel='poly')

# %% [markdown]
# With these results, we can see that poly have better results than rbf. So let's keep this kernel.
#
# In the end, for this second model we have:

# %%
y_pred = svc_best.predict(X_test)

print("Classification report on the test set with best parameters:")
print(classification_report(y_test, y_pred))
# Out:
# Classification report on the test set with best parameters:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       201
#            1       0.98      0.98      0.98       299
#
#     accuracy                           0.98       500
#    macro avg       0.98      0.98      0.98       500
# weighted avg       0.98      0.98      0.98       500
